# %%
import fitz
doc=fitz.open("./Unit 4_ Operators and Expression.pdf")
all_text=""
for page in doc:
    all_text+=page.get_text()+"\n"

doc.close()
print(all_text)
# Out:
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 1
# C Programming                                                                                                                 BIT
# Unit-4
# Operators and Expression
# Operators
# -
# An operator is a symbol that operates on single or multiple data items.
# -
# Used in program to perform certain mathematical or logical manipulations.
# E.g. In a simple expression 2+3, the symbol “+” is called an operator which operates on
# two data items 2 and 3.
# - The data items that operator act upon are called operands.
#
# Expression
# -
# An expression is a combination of variables, constants and operators written according to
# syntax of the language.
# E.g. 7+8, x+y*z, a>b
#
# Types of operator
# C operators can be classified into following types:
#  Arithmetic Operators
#  Relational Operators
#  Logical Operators
#  Assignment Operators
#  Increment and Decrement Operators
#  Conditional Operators
#  Bitwise Operators
#  Special Operators
#
# Arithmetic Operators
# Arithmetic operators are used to perform arithmetic operations. There are five arithmetic
# operators:
#
#
# Division Rule:
# -
# int/int = int
# -
# float/float = float
# -
# int/float = float
# -
# float/int = float
#
# Note: For modulo operator, the sign of the result is always the sign of the first operand.
# E.g. 10%3=1, -10%3=-1, -10%-3=-1, 10%-3=1
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 2
# C Programming                                                                                                                 BIT
# /* Program to Perform Arithmetic Operations in C */
# #include<stdio.h>
# int main()
# {
#  int a = 12, b = 3;
#  int add, sub, mul, div, mod;
#  add = a + b;
#  sub = a - b;
#  mul = a * b;
#  div = a / b;
#  mod = a % b;
#  printf("Addition of two numbers a, b is : %d\n", add);
#  printf("Subtraction of two numbers a, b is : %d\n", sub);
#  printf("Multiplication of two numbers a, b is : %d\n", mul);
#  printf("Division of two numbers a, b is : %d\n", div);
#  printf("Modulus of two numbers a, b is : %d\n", mod);
# }
#
# Relational Operators
# -
# Relational operators are used to compare two operands and taking decisions based on
# their relation.
# -
# Result of relational expression is either True(1) or False(0).
# -
# Relational operators are used in decision making and loops.
# -
# Relational operators are:
#
# /* Program to compare two numbers whether they are equal or not in C */
# #include <stdio.h>
# int main()
# {
#    int m=40, n=20;
#    if (m == n)
#    {
#        printf("m and n are equal");
#    }
#    else
#    {
#        printf("m and n are not equal");
#    }
#  }
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 3
# C Programming                                                                                                                 BIT
# Logical Operators
# -
# Logical operators are used to compare logical and relational expression.
# -
# The operands of logical operators must be either Boolean value (1 or 0) or expression that
# produces Boolean value.
# -
# The output of these operators is always 0 (flase) or 1 (true).
# -
# The logical operators are:
#
#
# Truth table for logical operators:
#
#
#
# /* C program to demonstrate working of logical operators */
# #include <stdio.h>
# int main()
# {
#     int a = 10, b = 4, c = 10, d = 20;
#
#     // logical AND example
#     if (a > b && c == d)
#         printf("a is greater than b AND c is equal to d\n");
#     else
#         printf("AND condition not satisfied\n");
#
#     // logical OR example
#     if (a > b || c == d)
#         printf("a is greater than b OR c is equal to d\n");
#     else
#         printf("Neither a is greater than b nor c is equal to d\n");
#
#     // logical NOT example
#     if (!a)
#         printf("a is zero\n");
#     else
#         printf("a is not zero");
#
#     return 0;
# }
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 4
# C Programming                                                                                                                 BIT
# Assignment Operator
# -
# Assignment operators are used to assign the result of an expression to a variable.
# -
# The mostly used assignment operator is ‘=’.
# -
# C also supports shorthand assignment operators which simplify operation with
# assignment.
#
#
#
# /* program to demonstrate working of Assignment operators */
#
# #include <stdio.h>
# int main()
# {
#     int a = 10;
#
#
#
#
#     printf("Value of a is %d\n", a);
#
# //10
#     a += 10;
#     printf("Value of a is %d\n", a);
#
# //20
#     a -= 10;
#     printf("Value of a is %d\n", a);
#
#  //10
#     a *= 10;
#     printf("Value of a is %d\n", a);
#
# //100
#     a /= 10;
#     printf("Value of a is %d\n", a);
#
#  //10
#     return 0;
# }
#
# Increment and Decrement Operators
# -
# Increment operator is used to increase the value of an operand by 1.
# -
# Decrement operator is used to decrease the value of an operand by 1.
#
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 5
# C Programming                                                                                                                 BIT
# Pre-increment operator (++a): the value is incremented first and then the expression is
# evaluated.
# E.g. a= 10; b=++a; after this statement, a= 11, b = 11.
# Post-increment operator (a++): the expression is evaluated first and then the value is
# incremented.
# E.g. a= 10; b=a++; after this statement, a= 11, b = 10.
# Pre-decrement operator (- -a): the value is decremented first and then the expression is
# evaluated.
# E.g. a= 10; b=--a; after this statement, a= 9, b = 9.
# Post-decrement operator (a- -): the expression is evaluated first and then the value is
# decremented.
# E.g. a= 10; b=a--; after this statement, a= 9, b = 10.
#
#
# /* program to demonstrate working of increment and decrement operators */
#
# #include <stdio.h>
# int main()
# {
#     int a = 5;
#     int b = 6;
#     printf("a=%d, b=%d",a,b);   //a=5, b=6
#     b=++a;
#     printf("a=%d, b=%d",a,b);   //a=6,b=6
#     b=a++;
#     printf("a=%d, b=%d",a,b);   //a=7,b=6
#     b=a--;
#     printf("a=%d, b=%d",a,b);   //a=6,b=7
#     b=--a;
#     printf("a=%d, b=%d",a,b);   //a=5, b=5
#     return 0;
# }
#
# Conditional Operator (Ternary Operator)
# -
# It takes three arguments.
# -
# Conditional operators return one value if condition is true and returns another value if
# condition is false.
# Syntax:
# (condition) ? value_if_true : value_if_false
#
# E.g. (a>b) ? 1 : 0;
# if a>b
#     return 1;
# else
#    return 0;
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 6
# C Programming                                                                                                                 BIT
# Q. Write a program to read two numbers from user and determine the larger number using
# conditional (ternary) operator.
# #include <stdio.h>
# int main()
# {
#    int n1, n2, larger;
#    printf("Enter two numbers:");
#    scanf("%d%d",&n1,&n2);
#    larger = (n1>n2)?n1:n2;
#    printf("The larger number is %d", larger);
#    return 0;
# }
#
# Bitwise Operator
# -
# Bitwise operators are used for manipulating data at bit level.
# -
# These operators are used for testing the bits or shifting them to the left or to the right.
# -
# Can be applied only to integer-type operands and not to float or double.
# -
# Three types of bitwise operators:
# (i) Bitwise logical operators
# (ii) Bitwise shift operators
# (iii) One’s compliment operator
#
# Bitwise logical operators:
# -
# Performs logical tests between two integer-type operands.
# -
# These operators work on their operands bit-by-bit starting from the least significant (i.e.
# rightmost) bit.
# -
# Three logical bitwise operators:
#  Bitwise AND (&): The result of ANDing operation is 1 if both the bits have a value 1;
# otherwise it is 0.
#  Bitwise OR (|): The result of ORing operation is 1 if either of the bits have value of 1;
# otherwise it is 0.
#  Bitwise XOR (^): The result of exclusive ORing operations is 1 only if one of the bits
# have a value of 1; otherwise it is 0.
#
# Truth table for bitwise operators (AND, OR, XOR)
#
#
# E.g.
# If a = 65, b=15
# Equivalent binary values of 65 = 0100 0001; 15 = 0000 1111
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 7
# C Programming                                                                                                                 BIT
#
# Bitwise shift operators:
# -
# Are used to move bit patterns either to left or to the right.
# -
# There are two bitwise shift operators:
#  Left shift(<<): Causes the operand to be shifted to the left by n positions.
# operand<<n
# The leftmost n bits in the original bit pattern will be lost and the rightmost n bits empty
# position will be filled with 0’s.
#  Right shift(>>): Causes the operand to be shifted to the right by n positions.
# operand<<n
# The empty leftmost n bits positions will be filled with 0’s, if the operand is an unsigned
# integer.
#       E.g.
#        If a =15; Equivalent binary value of a is 0000 1111
#
#
#
#
# 1
# 0
# 1
# 0
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 8
# C Programming                                                                                                                 BIT
# Bitwise one’s complement operator:
# -
# It is a unary operator which inverts all the bits represented by its operand. This means that
# all 0s becomes 1s and 1s becomes 0s.
# E.g.
# If a =15; Equivalent binary value of a is 0000 1111
#
#
# /* program to demonstrate working of bitwise operator */
#
# #include <stdio.h>
# void main()
# {
#    int a=65,b=15,AND, OR, XOR;
#    AND = a&b;
#    OR = a|b;
#    XOR = a^b;
#    printf("AND of a and b=%d\n",AND);
#    printf("OR of a and b=%d\n",OR);
#    printf("XOR of a and b=%d\n",XOR);
# }
# #include <stdio.h>
# void main()
# {
#    unsigned int a=15, left, right;
#    left = a<<3;
#    right = a>>2;
#    printf("%d\n", left);
#    printf("%d\n",right);
# }
#
#
# Special Operators
#  Comma operator (,):
# -
# The comma operator can be used link related expressions together.
# -
# A comma-linked list of expression are evaluated from left-to-right and the value of the
# rightmost expression is the value of the combined expressions.
# E.g. X=(a=5, b=10, a+b);
# -  The first assign the value 5 to a
# -  Assign the value 10 to b
# -  Assign sum(a+b) to X
#
#  Sizeof operator
# -
# It is used with an operand to return the number of bytes it occupies.
# -
# The operand may be constant, variable or a data type qualifier.
#
# E.g.
#
#
#
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 9
# C Programming                                                                                                                 BIT
# #include <stdio.h>
# int main()
# {
#     int a;
#     float b;
#     double c;
#     char d;
#     printf("Size of int=%lu bytes\n",sizeof(a));
#     printf("Size of float=%lu bytes\n",sizeof(b));
#     printf("Size of double=%lu bytes\n",sizeof(c));
#     printf("Size of char=%lu byte\n",sizeof(d));
#     return 0;
# }
#
#
# Operator precedence and associativity
# -
# The precedence is used to determine how an expression involving more than one operator
# is evaluated.
# -
# There are distinct level of precedence.
# -
# The operator at the higher level of precedence are evaluated first.
# -
# Operators of same precedence are evaluated either from “left to right” or “right to left”
# depending on the level also known as associativity.
#
#
#
#
#
#
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 10
# C Programming                                                                                                                 BIT
# Type conversion in expressions
# -
# When variables and constants of different types are combined in an expression then they
# are converted to same data type.
# -
# The process of converting one predefined type into another is called type conversion.
# -
# Type conversion in C can be classified into the following two types:
#
# 1. Implicit Type Conversion:
# -
# When the type conversion is performed automatically by the compiler without
# programmer‘s intervention, such type of conversion is known as implicit type
# conversion or type promotion.
# -
# When the expression contains different types of data items, the operand with a lower
# rank will be converted to the type of higher rank operand.
#
#
#      E.g.
# #include <stdio.h>
# int main()
# {
#
#      int  x = 13;
# // integer x
#
#      char c = 'a';
# // character c
#
#      float sum;
#
#      x = x + c;
#  // c implicitly converted to int. ASCII ('a'=97)
#
#      sum = x + 1.0;    // x is implicitly converted to float
#
#      printf("x = %d, sum = %f", x, sum);
#
#      return 0;
# }
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 11
# C Programming                                                                                                                 BIT
# 2. Explicit Type Conversion:
# -
# The type conversion performed by the programmer by posing the data type of the
# expression of specific type is known as explicit type conversion.
# -
# The explicit type conversion is also known as type casting.
# -
# Type casting in C is done in the following form:
# (data_type)expression;
# where, data_type is any valid C data type, and expression may be constant, variable
# or expression.
#
#      E.g.
# #include<stdio.h>
# int main()
# {
#
#     float a = 1.2;
#
#     int b;
#
#     b = (int)a + 1;
#
# // a is explicitly converted to int type
#
#     printf("Value of a is %f\n", a);
#
#     printf("Value of b is %d\n",b);
#
#     return 0;
# }
#
#
#
#
#
# Some Q &A
#
# Q. Find the value of ‘a’ in each of the following statements:
# int i=2, j=5, k=7
# float a=1.5, b=2.5, c=3.5
#
# i)  a = c - i/j + c/k
#         = 3.5 - 2/5 + 3.5/7
#         = 3.5 – 0 + 0.5
#         = 4
#
# ii) a = (b+4)%(c+2)
#         = (2.5+4)%(3.5+2)
#         = 6.5%5.5
#         = Not valid
#
# iii)  a = c + k%2 + b
#         = 3.5 + 7%2 + 2.5
#         = 3.5 + 1+ 2.5
#         = 7
#
# int/int = int, so 2/5= 0.4 = 0 (int part)
#
#
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 12
# C Programming                                                                                                                 BIT
# Q. Use the value initially assigned to the variable for each expression. Find the value of
# following operations.
#
# int a=8, b=5;
#
# float x=0.005, y=-0.01;
#
# i)  (x>y)&&(a>0)||(b<5);
#      = (0.005>-0.01)&&(8>0)||(5<5)
#      = (1)&&(1)||(0)
#      = 1 || 0
#      = 1
#
# ii)  (a>b)?a:b;
#      = (8>5)?8:5;
#      = 8

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
splitter=RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
    separators=["\n\n", "\n", ".", " "]
)
chunks=splitter.split_text(all_text)
for i,chunk in enumerate(chunks,1):
  print(f" Chunk[i] ")
  print(chunk)
# Out:
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 1
# C Programming                                                                                                                 BIT
# Unit-4
# Operators and Expression
# Operators
# -
# An operator is a symbol that operates on single or multiple data items.
# -
# Used in program to perform certain mathematical or logical manipulations.
# E.g. In a simple expression 2+3, the symbol “+” is called an operator which operates on
# two data items 2 and 3.
# - The data items that operator act upon are called operands.
#
# Expression
# -
# An expression is a combination of variables, constants and operators written according to
# syntax of the language.
# E.g. 7+8, x+y*z, a>b
#
# Types of operator
# C operators can be classified into following types:
#  Arithmetic Operators
#  Relational Operators
#  Logical Operators
#  Assignment Operators
#  Increment and Decrement Operators
#  Chunk[i]
# C operators can be classified into following types:
#  Arithmetic Operators
#  Relational Operators
#  Logical Operators
#  Assignment Operators
#  Increment and Decrement Operators
#  Conditional Operators
#  Bitwise Operators
#  Special Operators
#
# Arithmetic Operators
# Arithmetic operators are used to perform arithmetic operations. There are five arithmetic
# operators:
#
#
# Division Rule:
# -
# int/int = int
# -
# float/float = float
# -
# int/float = float
# -
# float/int = float
#
# Note: For modulo operator, the sign of the result is always the sign of the first operand.
# E.g. 10%3=1, -10%3=-1, -10%-3=-1, 10%-3=1
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 2
# C Programming                                                                                                                 BIT
# /* Program to Perform Arithmetic Operations in C */
# #include<stdio.h>
# int main()
# {
#  int a = 12, b = 3;
#  int add, sub, mul, div, mod;
#  add = a + b;
#  sub = a - b;
#  mul = a * b;
#  div = a / b;
#  mod = a % b;
#  printf("Addition of two numbers a, b is : %d\n", add);
#  printf("Subtraction of two numbers a, b is : %d\n", sub);
#  printf("Multiplication of two numbers a, b is : %d\n", mul);
#  printf("Division of two numbers a, b is : %d\n", div);
#  printf("Modulus of two numbers a, b is : %d\n", mod);
# }
#
# Relational Operators
# -
# Relational operators are used to compare two operands and taking decisions based on
# their relation.
# -
# Result of relational expression is either True(1) or False(0).
# -
#  Chunk[i]
# Relational Operators
# -
# Relational operators are used to compare two operands and taking decisions based on
# their relation.
# -
# Result of relational expression is either True(1) or False(0).
# -
# Relational operators are used in decision making and loops.
# -
# Relational operators are:
#
# /* Program to compare two numbers whether they are equal or not in C */
# #include <stdio.h>
# int main()
# {
#    int m=40, n=20;
#    if (m == n)
#    {
#        printf("m and n are equal");
#    }
#    else
#    {
#        printf("m and n are not equal");
#    }
#  }
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 3
# C Programming                                                                                                                 BIT
# Logical Operators
# -
# Logical operators are used to compare logical and relational expression.
# -
# The operands of logical operators must be either Boolean value (1 or 0) or expression that
# produces Boolean value.
# -
# The output of these operators is always 0 (flase) or 1 (true).
# -
# The logical operators are:
#
#
# Truth table for logical operators:
#
#
#
# /* C program to demonstrate working of logical operators */
# #include <stdio.h>
# int main()
# {
#     int a = 10, b = 4, c = 10, d = 20;
#
#     // logical AND example
#     if (a > b && c == d)
#         printf("a is greater than b AND c is equal to d\n");
#     else
#         printf("AND condition not satisfied\n");
#
#     // logical OR example
#  Chunk[i]
# if (a > b && c == d)
#         printf("a is greater than b AND c is equal to d\n");
#     else
#         printf("AND condition not satisfied\n");
#
#     // logical OR example
#     if (a > b || c == d)
#         printf("a is greater than b OR c is equal to d\n");
#     else
#         printf("Neither a is greater than b nor c is equal to d\n");
#
#     // logical NOT example
#     if (!a)
#         printf("a is zero\n");
#     else
#         printf("a is not zero");
#
#     return 0;
# }
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 4
# C Programming                                                                                                                 BIT
# Assignment Operator
# -
# Assignment operators are used to assign the result of an expression to a variable.
# -
# The mostly used assignment operator is ‘=’.
# -
# C also supports shorthand assignment operators which simplify operation with
# assignment.
#
#
#
# /* program to demonstrate working of Assignment operators */
#
# #include <stdio.h>
# int main()
# {
#     int a = 10;
#
#
#
#
#     printf("Value of a is %d\n", a);
#
# //10
#     a += 10;
#     printf("Value of a is %d\n", a);
#
# //20
#     a -= 10;
#     printf("Value of a is %d\n", a);
#
#  //10
#     a *= 10;
#     printf("Value of a is %d\n", a);
#
# //100
#     a /= 10;
#     printf("Value of a is %d\n", a);
#
#  //10
#     return 0;
# }
#  Chunk[i]
# printf("Value of a is %d\n", a);
#
#  //10
#     a *= 10;
#     printf("Value of a is %d\n", a);
#
# //100
#     a /= 10;
#     printf("Value of a is %d\n", a);
#
#  //10
#     return 0;
# }
#
# Increment and Decrement Operators
# -
# Increment operator is used to increase the value of an operand by 1.
# -
# Decrement operator is used to decrease the value of an operand by 1.
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 5
# C Programming                                                                                                                 BIT
# Pre-increment operator (++a): the value is incremented first and then the expression is
# evaluated.
# E.g. a= 10; b=++a; after this statement, a= 11, b = 11.
# Post-increment operator (a++): the expression is evaluated first and then the value is
# incremented.
# E.g. a= 10; b=a++; after this statement, a= 11, b = 10.
# Pre-decrement operator (- -a): the value is decremented first and then the expression is
# evaluated.
# E.g. a= 10; b=--a; after this statement, a= 9, b = 9.
# Post-decrement operator (a- -): the expression is evaluated first and then the value is
# decremented.
# E.g. a= 10; b=a--; after this statement, a= 9, b = 10.
#
#
# /* program to demonstrate working of increment and decrement operators */
#
# #include <stdio.h>
#  Chunk[i]
# decremented.
# E.g. a= 10; b=a--; after this statement, a= 9, b = 10.
#
#
# /* program to demonstrate working of increment and decrement operators */
#
# #include <stdio.h>
# int main()
# {
#     int a = 5;
#     int b = 6;
#     printf("a=%d, b=%d",a,b);   //a=5, b=6
#     b=++a;
#     printf("a=%d, b=%d",a,b);   //a=6,b=6
#     b=a++;
#     printf("a=%d, b=%d",a,b);   //a=7,b=6
#     b=a--;
#     printf("a=%d, b=%d",a,b);   //a=6,b=7
#     b=--a;
#     printf("a=%d, b=%d",a,b);   //a=5, b=5
#     return 0;
# }
#
# Conditional Operator (Ternary Operator)
# -
# It takes three arguments.
# -
# Conditional operators return one value if condition is true and returns another value if
# condition is false.
# Syntax:
# (condition) ? value_if_true : value_if_false
#
# E.g. (a>b) ? 1 : 0;
# if a>b
#     return 1;
# else
#    return 0;
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 6
# C Programming                                                                                                                 BIT
# Q. Write a program to read two numbers from user and determine the larger number using
# conditional (ternary) operator.
# #include <stdio.h>
# int main()
# {
#    int n1, n2, larger;
#    printf("Enter two numbers:");
#    scanf("%d%d",&n1,&n2);
#    larger = (n1>n2)?n1:n2;
#    printf("The larger number is %d", larger);
#    return 0;
# }
#
# Bitwise Operator
# -
# Bitwise operators are used for manipulating data at bit level.
# -
# These operators are used for testing the bits or shifting them to the left or to the right.
# -
# Can be applied only to integer-type operands and not to float or double.
# -
# Three types of bitwise operators:
# (i) Bitwise logical operators
# (ii) Bitwise shift operators
# (iii) One’s compliment operator
#  Chunk[i]
# -
# Three types of bitwise operators:
# (i) Bitwise logical operators
# (ii) Bitwise shift operators
# (iii) One’s compliment operator
#
# Bitwise logical operators:
# -
# Performs logical tests between two integer-type operands.
# -
# These operators work on their operands bit-by-bit starting from the least significant (i.e.
# rightmost) bit.
# -
# Three logical bitwise operators:
#  Bitwise AND (&): The result of ANDing operation is 1 if both the bits have a value 1;
# otherwise it is 0.
#  Bitwise OR (|): The result of ORing operation is 1 if either of the bits have value of 1;
# otherwise it is 0.
#  Bitwise XOR (^): The result of exclusive ORing operations is 1 only if one of the bits
# have a value of 1; otherwise it is 0.
#
# Truth table for bitwise operators (AND, OR, XOR)
#
#
# E.g.
# If a = 65, b=15
# Equivalent binary values of 65 = 0100 0001; 15 = 0000 1111
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 7
# C Programming                                                                                                                 BIT
#
# Bitwise shift operators:
# -
# Are used to move bit patterns either to left or to the right.
# -
# There are two bitwise shift operators:
#  Left shift(<<): Causes the operand to be shifted to the left by n positions.
# operand<<n
# The leftmost n bits in the original bit pattern will be lost and the rightmost n bits empty
# position will be filled with 0’s.
#  Right shift(>>): Causes the operand to be shifted to the right by n positions.
# operand<<n
# The empty leftmost n bits positions will be filled with 0’s, if the operand is an unsigned
# integer.
#       E.g.
#        If a =15; Equivalent binary value of a is 0000 1111
#
#
#
#
# 1
# 0
# 1
# 0
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 8
# C Programming                                                                                                                 BIT
# Bitwise one’s complement operator:
# -
# It is a unary operator which inverts all the bits represented by its operand. This means that
# all 0s becomes 1s and 1s becomes 0s.
# E.g.
# If a =15; Equivalent binary value of a is 0000 1111
#
#
# /* program to demonstrate working of bitwise operator */
#
# #include <stdio.h>
# void main()
# {
#    int a=65,b=15,AND, OR, XOR;
#    AND = a&b;
#    OR = a|b;
#    XOR = a^b;
#    printf("AND of a and b=%d\n",AND);
#    printf("OR of a and b=%d\n",OR);
#    printf("XOR of a and b=%d\n",XOR);
# }
# #include <stdio.h>
# void main()
# {
#    unsigned int a=15, left, right;
#    left = a<<3;
#    right = a>>2;
#    printf("%d\n", left);
#    printf("%d\n",right);
# }
#
#
# Special Operators
#  Comma operator (,):
# -
#  Chunk[i]
# void main()
# {
#    unsigned int a=15, left, right;
#    left = a<<3;
#    right = a>>2;
#    printf("%d\n", left);
#    printf("%d\n",right);
# }
#
#
# Special Operators
#  Comma operator (,):
# -
# The comma operator can be used link related expressions together.
# -
# A comma-linked list of expression are evaluated from left-to-right and the value of the
# rightmost expression is the value of the combined expressions.
# E.g. X=(a=5, b=10, a+b);
# -  The first assign the value 5 to a
# -  Assign the value 10 to b
# -  Assign sum(a+b) to X
#
#  Sizeof operator
# -
# It is used with an operand to return the number of bytes it occupies.
# -
# The operand may be constant, variable or a data type qualifier.
#
# E.g.
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 9
# C Programming                                                                                                                 BIT
# #include <stdio.h>
# int main()
# {
#     int a;
#     float b;
#     double c;
#     char d;
#     printf("Size of int=%lu bytes\n",sizeof(a));
#     printf("Size of float=%lu bytes\n",sizeof(b));
#     printf("Size of double=%lu bytes\n",sizeof(c));
#     printf("Size of char=%lu byte\n",sizeof(d));
#     return 0;
# }
#
#
# Operator precedence and associativity
# -
# The precedence is used to determine how an expression involving more than one operator
# is evaluated.
# -
# There are distinct level of precedence.
# -
# The operator at the higher level of precedence are evaluated first.
# -
# Operators of same precedence are evaluated either from “left to right” or “right to left”
# depending on the level also known as associativity.
#  Chunk[i]
# -
# Operators of same precedence are evaluated either from “left to right” or “right to left”
# depending on the level also known as associativity.
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 10
# C Programming                                                                                                                 BIT
# Type conversion in expressions
# -
# When variables and constants of different types are combined in an expression then they
# are converted to same data type.
# -
# The process of converting one predefined type into another is called type conversion.
# -
# Type conversion in C can be classified into the following two types:
#
# 1. Implicit Type Conversion:
# -
# When the type conversion is performed automatically by the compiler without
# programmer‘s intervention, such type of conversion is known as implicit type
# conversion or type promotion.
# -
# When the expression contains different types of data items, the operand with a lower
# rank will be converted to the type of higher rank operand.
#
#
#      E.g.
#  Chunk[i]
# -
# When the expression contains different types of data items, the operand with a lower
# rank will be converted to the type of higher rank operand.
#
#
#      E.g.
# #include <stdio.h>
# int main()
# {
#
#      int  x = 13;
# // integer x
#
#      char c = 'a';
# // character c
#
#      float sum;
#
#      x = x + c;
#  // c implicitly converted to int. ASCII ('a'=97)
#
#      sum = x + 1.0;    // x is implicitly converted to float
#
#      printf("x = %d, sum = %f", x, sum);
#
#      return 0;
# }
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 11
# C Programming                                                                                                                 BIT
# 2. Explicit Type Conversion:
# -
# The type conversion performed by the programmer by posing the data type of the
# expression of specific type is known as explicit type conversion.
# -
# The explicit type conversion is also known as type casting.
# -
# Type casting in C is done in the following form:
# (data_type)expression;
# where, data_type is any valid C data type, and expression may be constant, variable
# or expression.
#
#      E.g.
# #include<stdio.h>
# int main()
# {
#
#     float a = 1.2;
#
#     int b;
#
#     b = (int)a + 1;
#
# // a is explicitly converted to int type
#
#     printf("Value of a is %f\n", a);
#
#     printf("Value of b is %d\n",b);
#
#     return 0;
# }
#
#
#
#
#
# Some Q &A
#  Chunk[i]
# b = (int)a + 1;
#
# // a is explicitly converted to int type
#
#     printf("Value of a is %f\n", a);
#
#     printf("Value of b is %d\n",b);
#
#     return 0;
# }
#
#
#
#
#
# Some Q &A
#
# Q. Find the value of ‘a’ in each of the following statements:
# int i=2, j=5, k=7
# float a=1.5, b=2.5, c=3.5
#
# i)  a = c - i/j + c/k
#         = 3.5 - 2/5 + 3.5/7
#         = 3.5 – 0 + 0.5
#         = 4
#
# ii) a = (b+4)%(c+2)
#         = (2.5+4)%(3.5+2)
#         = 6.5%5.5
#         = Not valid
#
# iii)  a = c + k%2 + b
#         = 3.5 + 7%2 + 2.5
#         = 3.5 + 1+ 2.5
#         = 7
#
# int/int = int, so 2/5= 0.4 = 0 (int part)
#  Chunk[i]
# https://collegenote.pythonanywhere.com/                                                               College Note
#
# 12
# C Programming                                                                                                                 BIT
# Q. Use the value initially assigned to the variable for each expression. Find the value of
# following operations.
#
# int a=8, b=5;
#
# float x=0.005, y=-0.01;
#
# i)  (x>y)&&(a>0)||(b<5);
#      = (0.005>-0.01)&&(8>0)||(5<5)
#      = (1)&&(1)||(0)
#      = 1 || 0
#      = 1
#
# ii)  (a>b)?a:b;
#      = (8>5)?8:5;
#      = 8

# %%
def load_and_chunk_pdf(pdf_path):
    doc=fitz.open(pdf_path)
    chunks=[]
    
    for page_num,page in enumerate(doc,start=1):
        text=page.get_text()
        if text.strip():
            chunks.append({
                "filename":pdf_path.split("/")[-1],
                "text":text,
                "page_no":page_num
            })
    doc.close()
    return chunks

pdf_chunks=load_and_chunk_pdf('./Unit 4_ Operators and Expression.pdf')
pdf_chunks[-5:]
# Out:
# [{'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n8 \nC Programming                                                                                                                 BIT \nBitwise one’s complement operator: \n- \nIt is a unary operator which inverts all the bits represented by its operand. This means that \nall 0s becomes 1s and 1s becomes 0s. \nE.g. \nIf a =15; Equivalent binary value of a is 0000 1111 \n \n \n/* program to demonstrate working of bitwise operator */ \n   \n#include <stdio.h> \nvoid main() \n{ \n   int a=65,b=15,AND, OR, XOR; \n   AND = a&b; \n   OR = a|b; \n   XOR = a^b; \n   printf("AND of a and b=%d\\n",AND); \n   printf("OR of a and b=%d\\n",OR); \n   printf("XOR of a and b=%d\\n",XOR); \n} \n#include <stdio.h> \nvoid main() \n{ \n   unsigned int a=15, left, right; \n   left = a<<3; \n   right = a>>2; \n   printf("%d\\n", left); \n   printf("%d\\n",right); \n} \n \n \nSpecial Operators \n\uf0a7 Comma operator (,): \n- \nThe comma operator can be used link related expressions together. \n- \nA comma-linked list of expression are evaluated from left-to-right and the value of the \nrightmost expression is the value of the combined expressions. \nE.g. X=(a=5, b=10, a+b); \n-  The first assign the value 5 to a \n-  Assign the value 10 to b \n-  Assign sum(a+b) to X \n \n\uf0a7 Sizeof operator \n- \nIt is used with an operand to return the number of bytes it occupies. \n- \nThe operand may be constant, variable or a data type qualifier. \n \nE.g. \n \n \n \n',
#   'page_no': 8},
#  {'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n9 \nC Programming                                                                                                                 BIT \n#include <stdio.h> \nint main() \n{ \n    int a; \n    float b; \n    double c; \n    char d; \n    printf("Size of int=%lu bytes\\n",sizeof(a)); \n    printf("Size of float=%lu bytes\\n",sizeof(b)); \n    printf("Size of double=%lu bytes\\n",sizeof(c)); \n    printf("Size of char=%lu byte\\n",sizeof(d)); \n    return 0; \n} \n \n \nOperator precedence and associativity \n- \nThe precedence is used to determine how an expression involving more than one operator \nis evaluated. \n- \nThere are distinct level of precedence. \n- \nThe operator at the higher level of precedence are evaluated first. \n- \nOperators of same precedence are evaluated either from “left to right” or “right to left” \ndepending on the level also known as associativity. \n \n            \n \n \n \n \n',
#   'page_no': 9},
#  {'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n10 \nC Programming                                                                                                                 BIT \nType conversion in expressions \n- \nWhen variables and constants of different types are combined in an expression then they \nare converted to same data type.  \n- \nThe process of converting one predefined type into another is called type conversion. \n- \nType conversion in C can be classified into the following two types: \n \n1. Implicit Type Conversion: \n- \nWhen the type conversion is performed automatically by the compiler without \nprogrammer‘s intervention, such type of conversion is known as implicit type \nconversion or type promotion. \n- \nWhen the expression contains different types of data items, the operand with a lower \nrank will be converted to the type of higher rank operand. \n                               \n \n     E.g. \n#include <stdio.h> \nint main()  \n{ \n    \n     int  x = 13;      \n// integer x \n   \n     char c = \'a\';     \n// character c \n   \n     float sum; \n   \n     x = x + c;       \n // c implicitly converted to int. ASCII (\'a\'=97) \n   \n     sum = x + 1.0;    // x is implicitly converted to float \n   \n     printf("x = %d, sum = %f", x, sum);  \n   \n     return 0; \n} \n',
#   'page_no': 10},
#  {'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n11 \nC Programming                                                                                                                 BIT \n2. Explicit Type Conversion:  \n- \nThe type conversion performed by the programmer by posing the data type of the \nexpression of specific type is known as explicit type conversion.  \n- \nThe explicit type conversion is also known as type casting.  \n- \nType casting in C is done in the following form:  \n(data_type)expression;  \nwhere, data_type is any valid C data type, and expression may be constant, variable \nor expression. \n \n     E.g.  \n#include<stdio.h> \nint main() \n{ \n \n    float a = 1.2; \n \n    int b; \n \n    b = (int)a + 1; \n \n// a is explicitly converted to int type \n \n    printf("Value of a is %f\\n", a); \n \n    printf("Value of b is %d\\n",b); \n \n    return 0; \n} \n \n \n \n \n \nSome Q &A \n \nQ. Find the value of ‘a’ in each of the following statements: \nint i=2, j=5, k=7 \nfloat a=1.5, b=2.5, c=3.5 \n \ni)  a = c - i/j + c/k \n        = 3.5 - 2/5 + 3.5/7 \n        = 3.5 – 0 + 0.5 \n        = 4 \n \nii) a = (b+4)%(c+2) \n        = (2.5+4)%(3.5+2) \n        = 6.5%5.5 \n        = Not valid \n \niii)  a = c + k%2 + b \n        = 3.5 + 7%2 + 2.5 \n        = 3.5 + 1+ 2.5 \n        = 7 \n \nint/int = int, so 2/5= 0.4 = 0 (int part) \n',
#   'page_no': 11},
#  {'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n12 \nC Programming                                                                                                                 BIT \nQ. Use the value initially assigned to the variable for each expression. Find the value of \nfollowing operations. \n \nint a=8, b=5; \n \nfloat x=0.005, y=-0.01; \n \ni)  (x>y)&&(a>0)||(b<5); \n     = (0.005>-0.01)&&(8>0)||(5<5) \n     = (1)&&(1)||(0) \n     = 1 || 0 \n     = 1 \n \nii)  (a>b)?a:b; \n     = (8>5)?8:5; \n     = 8 \n \n',
#   'page_no': 12}]

# %%
from sentence_transformers import SentenceTransformer
import faiss
import json
import os

model = SentenceTransformer("all-MiniLM-L6-v2")
index_file = "myindex.faiss"
text_file = "mytext.json"

if os.path.exists(index_file):
    index = faiss.read_index(index_file)
else:
    index = faiss.IndexFlatL2(384)

if os.path.exists(text_file):
    with open(text_file, "r") as f:
        texts = json.load(f)
else:
    texts = []

def add_text(new_items):
    global index, texts

    raw_texts = [item["text"] for item in new_items]
    embeddings = model.encode(raw_texts, normalize_embeddings=True).astype("float32")

    index.add(embeddings)
    texts.extend(new_items)

    faiss.write_index(index, index_file)
    with open(text_file, "w") as f:
        json.dump(texts, f)

add_text(pdf_chunks)

# %%
def retrive(query, top_k=5):
    query_emb = model.encode([query], normalize_embeddings=True).astype("float32")
    D, I = index.search(query_emb, top_k)
    return [texts[i] for i in I[0] if i != -1]

retrive("Types of opetarors")
# Out:
# [{'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n1 \nC Programming                                                                                                                 BIT \nUnit-4 \nOperators and Expression \nOperators \n- \nAn operator is a symbol that operates on single or multiple data items. \n- \nUsed in program to perform certain mathematical or logical manipulations. \nE.g. In a simple expression 2+3, the symbol “+” is called an operator which operates on \ntwo data items 2 and 3. \n- The data items that operator act upon are called operands. \n \nExpression \n- \nAn expression is a combination of variables, constants and operators written according to \nsyntax of the language. \nE.g. 7+8, x+y*z, a>b \n \nTypes of operator \nC operators can be classified into following types: \n\uf0b7 Arithmetic Operators \n\uf0b7 Relational Operators \n\uf0b7 Logical Operators \n\uf0b7 Assignment Operators \n\uf0b7 Increment and Decrement Operators \n\uf0b7 Conditional Operators \n\uf0b7 Bitwise Operators \n\uf0b7 Special Operators \n \nArithmetic Operators \nArithmetic operators are used to perform arithmetic operations. There are five arithmetic \noperators: \n         \n \nDivision Rule: \n- \nint/int = int \n- \nfloat/float = float \n- \nint/float = float \n- \nfloat/int = float \n \nNote: For modulo operator, the sign of the result is always the sign of the first operand. \nE.g. 10%3=1, -10%3=-1, -10%-3=-1, 10%-3=1 \n',
#   'page_no': 1},
#  {'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n10 \nC Programming                                                                                                                 BIT \nType conversion in expressions \n- \nWhen variables and constants of different types are combined in an expression then they \nare converted to same data type.  \n- \nThe process of converting one predefined type into another is called type conversion. \n- \nType conversion in C can be classified into the following two types: \n \n1. Implicit Type Conversion: \n- \nWhen the type conversion is performed automatically by the compiler without \nprogrammer‘s intervention, such type of conversion is known as implicit type \nconversion or type promotion. \n- \nWhen the expression contains different types of data items, the operand with a lower \nrank will be converted to the type of higher rank operand. \n                               \n \n     E.g. \n#include <stdio.h> \nint main()  \n{ \n    \n     int  x = 13;      \n// integer x \n   \n     char c = \'a\';     \n// character c \n   \n     float sum; \n   \n     x = x + c;       \n // c implicitly converted to int. ASCII (\'a\'=97) \n   \n     sum = x + 1.0;    // x is implicitly converted to float \n   \n     printf("x = %d, sum = %f", x, sum);  \n   \n     return 0; \n} \n',
#   'page_no': 10},
#  {'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n9 \nC Programming                                                                                                                 BIT \n#include <stdio.h> \nint main() \n{ \n    int a; \n    float b; \n    double c; \n    char d; \n    printf("Size of int=%lu bytes\\n",sizeof(a)); \n    printf("Size of float=%lu bytes\\n",sizeof(b)); \n    printf("Size of double=%lu bytes\\n",sizeof(c)); \n    printf("Size of char=%lu byte\\n",sizeof(d)); \n    return 0; \n} \n \n \nOperator precedence and associativity \n- \nThe precedence is used to determine how an expression involving more than one operator \nis evaluated. \n- \nThere are distinct level of precedence. \n- \nThe operator at the higher level of precedence are evaluated first. \n- \nOperators of same precedence are evaluated either from “left to right” or “right to left” \ndepending on the level also known as associativity. \n \n            \n \n \n \n \n',
#   'page_no': 9},
#  {'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n6 \nC Programming                                                                                                                 BIT \nQ. Write a program to read two numbers from user and determine the larger number using \nconditional (ternary) operator. \n#include <stdio.h> \nint main() \n{ \n   int n1, n2, larger; \n   printf("Enter two numbers:"); \n   scanf("%d%d",&n1,&n2); \n   larger = (n1>n2)?n1:n2; \n   printf("The larger number is %d", larger); \n   return 0; \n} \n \nBitwise Operator \n- \nBitwise operators are used for manipulating data at bit level. \n- \nThese operators are used for testing the bits or shifting them to the left or to the right. \n- \nCan be applied only to integer-type operands and not to float or double. \n- \nThree types of bitwise operators:  \n(i) Bitwise logical operators \n(ii) Bitwise shift operators \n(iii) One’s compliment operator \n \nBitwise logical operators: \n- \nPerforms logical tests between two integer-type operands. \n- \nThese operators work on their operands bit-by-bit starting from the least significant (i.e. \nrightmost) bit. \n- \nThree logical bitwise operators: \n\uf0a7 Bitwise AND (&): The result of ANDing operation is 1 if both the bits have a value 1; \notherwise it is 0. \n\uf0a7 Bitwise OR (|): The result of ORing operation is 1 if either of the bits have value of 1; \notherwise it is 0. \n\uf0a7 Bitwise XOR (^): The result of exclusive ORing operations is 1 only if one of the bits \nhave a value of 1; otherwise it is 0. \n \nTruth table for bitwise operators (AND, OR, XOR) \n         \n \nE.g. \nIf a = 65, b=15   \nEquivalent binary values of 65 = 0100 0001; 15 = 0000 1111 \n',
#   'page_no': 6},
#  {'filename': 'Unit 4_ Operators and Expression.pdf',
#   'text': ' \nhttps://collegenote.pythonanywhere.com/                                                               College Note \n \n11 \nC Programming                                                                                                                 BIT \n2. Explicit Type Conversion:  \n- \nThe type conversion performed by the programmer by posing the data type of the \nexpression of specific type is known as explicit type conversion.  \n- \nThe explicit type conversion is also known as type casting.  \n- \nType casting in C is done in the following form:  \n(data_type)expression;  \nwhere, data_type is any valid C data type, and expression may be constant, variable \nor expression. \n \n     E.g.  \n#include<stdio.h> \nint main() \n{ \n \n    float a = 1.2; \n \n    int b; \n \n    b = (int)a + 1; \n \n// a is explicitly converted to int type \n \n    printf("Value of a is %f\\n", a); \n \n    printf("Value of b is %d\\n",b); \n \n    return 0; \n} \n \n \n \n \n \nSome Q &A \n \nQ. Find the value of ‘a’ in each of the following statements: \nint i=2, j=5, k=7 \nfloat a=1.5, b=2.5, c=3.5 \n \ni)  a = c - i/j + c/k \n        = 3.5 - 2/5 + 3.5/7 \n        = 3.5 – 0 + 0.5 \n        = 4 \n \nii) a = (b+4)%(c+2) \n        = (2.5+4)%(3.5+2) \n        = 6.5%5.5 \n        = Not valid \n \niii)  a = c + k%2 + b \n        = 3.5 + 7%2 + 2.5 \n        = 3.5 + 1+ 2.5 \n        = 7 \n \nint/int = int, so 2/5= 0.4 = 0 (int part) \n',
#   'page_no': 11}]

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

from langchain_google_genai import ChatGoogleGenerativeAI

# Initialize LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    api_key="YOUR-API-KEY"
)


response = llm.invoke("What is a ternary operator in C?")
print(response)
# Out:
# content='In C, the ternary operator is a shorthand way of writing a simple `if-else` statement.  It\'s a conditional operator that takes three operands and evaluates to one of two values based on a condition.\n\n**Syntax:**\n\n```c\ncondition ? expression1 : expression2;\n```\n\n**How it works:**\n\n1. **Condition:** The `condition` is evaluated.  It must be an expression that results in a boolean value (true or false, represented by non-zero or zero respectively).\n\n2. **Evaluation:**\n   - If the `condition` is true (non-zero), `expression1` is evaluated and its value becomes the result of the entire ternary expression.\n   - If the `condition` is false (zero), `expression2` is evaluated and its value becomes the result of the entire ternary expression.\n\n**Example:**\n\n```c\n#include <stdio.h>\n\nint main() {\n  int a = 10, b = 20, max;\n\n  max = (a > b) ? a : b; //Ternary operator\n\n  printf("The maximum value is: %d\\n", max); // Output: The maximum value is: 20\n\n  return 0;\n}\n```\n\nIn this example:\n\n- `(a > b)` is the condition.  Since `a` (10) is not greater than `b` (20), the condition is false.\n- Therefore, `b` (20) is assigned to `max`.\n\n**Another Example with different data types:**\n\n```c\n#include <stdio.h>\n\nint main() {\n  int age = 25;\n  char *status = (age >= 18) ? "Adult" : "Minor"; \n  printf("Status: %s\\n", status); // Output: Status: Adult\n\n  return 0;\n}\n```\n\nHere, the ternary operator selects a string literal based on the age.\n\n\n**Important Note:**  While the ternary operator is concise, overuse can make code harder to read.  For complex conditional logic, a standard `if-else` statement is often preferred for better clarity.' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []} id='run--5771bd35-43d3-43a7-95b5-53c1ee4d392a-0' usage_metadata={'input_tokens': 8, 'output_tokens': 472, 'total_tokens': 480, 'input_token_details': {'cache_read': 0}}

# %%
import json
import re

def json_to_obj(json_str: str) -> dict:
    # Clean LLM-style triple backtick-wrapped JSON strings
    cleaned = re.sub(r'^```(?:json)?\s*|\s*```$', '', json_str.strip(), flags=re.IGNORECASE)

    try:
        return json.loads(cleaned)
    except json.JSONDecodeError as e:
        print("Failed to parse JSON:", e)
        return {}
def rag_answer(question):
    chunks=retrive(question)
    context=json.dumps(chunks)
    prompt_template = """
You are a helpful and intelligent study assistant. You are given a list of JSON objects as context, each representing extracted text from a PDF.

Each object contains:
- 'text': the actual content
- 'filename': the PDF file name
- 'page_no': the page number

Your task is to answer the student's question based **primarily** on the 'text' fields in the context. You may reason and infer the answer if the exact wording is not available, as long as your answer is clearly supported by the content.

# Context:
{context}

# Question:
{question}

# Instructions:
- Use only the 'text' field from the context entries for answering the question, but include the most relevant 'filename' and 'page_no' you used.
- Even if the original text is technical or unclear, rewrite the answer in a simple, **student-friendly** way that is easy to understand.
- You can use **Markdown formatting** (headings, bullet points, code blocks, tables, etc.) to make the answer more readable and structured.
- You **may infer** or **summarize** answers from the content to help students understand, even if the answer is not a perfect match.
- Avoid saying you don’t know unless the question is entirely unrelated to the context.
- Return a JSON object with:
  - "answer": your helpful, clear, Markdown-formatted answer
  - "filename": the filename of the most relevant entry you used
  - "page_no": the corresponding page number

- If the context contains **nothing relevant at all** to the question, return:
  ```json
  {{
    "answer": "I'm sorry, but I don't have enough information to answer that.",
    "filename": null,
    "page_no": null
  }}
  ```
Respond ONLY with a valid JSON object. Do not include any explanation, formatting, or extra text.
"""
    prompt=prompt_template.replace("{context}", context).replace("{question}", question)
    response=llm.invoke(prompt)
    obj=json_to_obj(response.content)
    return obj

answer=rag_answer("what are type of variables")

# %%
answer
# Out:
# {'answer': 'Based on the provided text from `Unit 4_ Operators and Expression.pdf`, page 9 and 10,  C programming uses several variable types:\n\n*   **int:**  Stores whole numbers (integers).\n*   **float:** Stores numbers with decimal points.\n*   **double:** Stores numbers with decimal points, typically with higher precision than `float`.\n*   **char:** Stores single characters.',
#  'filename': 'Unit 4_ Operators and Expression.pdf',
#  'page_no': 9}
